# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
#more_10=chipo(['item_price']>10)
chipo['item_price'] = chipo['item_price'].apply(lambda x : float(x[1:]))
chipo.dtypes
#chipo['item_price'] =chipo['item_price'].str.slice(1,5)
#chipo['item_price']=chipo['item_price'].astype(dtype=np.float64)
#chipo.nlargest(10,'item_price')
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
more_10=chipo[chipo['item_price'] > 10.00]
more_10.count()
# Out:
# order_id              1130
# quantity              1130
# item_name             1130
# choice_description    1123
# item_price            1130
# dtype: int64

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
Two=chipo[['item_name','item_price']]
Two.head()
# Out:
#                                item_name  item_price
# 0           Chips and Fresh Tomato Salsa        2.39
# 1                                   Izze        3.39
# 2                       Nantucket Nectar        3.39
# 3  Chips and Tomatillo-Green Chili Salsa        2.39
# 4                           Chicken Bowl       16.98

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
name=chipo.sort_values(['item_name'], ascending=(True))
name.head()
# Out:
#       order_id  quantity          item_name choice_description  item_price
# 3389      1360         2  6 Pack Soft Drink        [Diet Coke]       12.98
# 341        148         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 1849       749         1  6 Pack Soft Drink             [Coke]        6.49
# 1860       754         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 2713      1076         1  6 Pack Soft Drink             [Coke]        6.49

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
expensive=chipo.sort_values(['item_price'], ascending=(False))
expensive
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
# 409        178         3                  Chicken Bowl
# 1255       511         3                 Steak Burrito
# 3603      1443         3                 Steak Burrito
# 3636      1454         3               Chicken Burrito
# 3634      1454         3               Chicken Burrito
# 1514       616         3                  Chicken Bowl
# 3334      1336         3                    Steak Bowl
# 281        123         2              Steak Salad Bowl
# 613        253         2              Steak Salad Bowl
# 4427      1764         2                    Steak Bowl
# 1566       635         2                    Steak Bowl
# ...

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
veggie=chipo[chipo['item_name']=='Veggie Salad Bowl']['item_name'].count()
veggie
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times people orderd more than one Canned Soda?

# %%
chipo[(chipo['item_name']=='Canned Soda') & (chipo['quantity'] > 1)]['item_name'].count()
# Out:
# 20

# %%
#chipo.groupby('item_name').max()

# %%
chipo['item_price']= chipo['item_price'].apply(lambda x:float(x.replace("$", '')) )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-40e8b1f8adf7> in <module>()
# ----> 1 chipo['item_price']= chipo['item_price'].apply(lambda x:float(x.replace("$", '')) )
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-19-40e8b1f8adf7> in <lambda>(x)
# ----> 1 chipo['item_price']= chipo['item_price'].apply(lambda x:float(x.replace("$", '')) )
#
# AttributeError: 'float' object has no attribute 'replace'
